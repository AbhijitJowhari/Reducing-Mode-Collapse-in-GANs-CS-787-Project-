# %% [markdown]
# Importing Libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# Transforming image to tensors

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %% [markdown]
# Loading the cifar-10 dataset

# %%
train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# Defining GAN hyperparameters

# %%
latent_dim = 100
lr = 0.0002
beta1 = 0.5
beta2 = 0.999
num_epochs = 10

# %% [markdown]
# Generator

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128 * 8 * 8),
            nn.ReLU(),
            nn.Unflatten(1, (128, 8, 8)),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128, momentum=0.78),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64, momentum=0.78),
            nn.ReLU(),
            nn.Conv2d(64, 3, kernel_size=3, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img

# %% [markdown]
# Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
        nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
        nn.ZeroPad2d((0, 1, 0, 1)),
        nn.BatchNorm2d(64, momentum=0.82),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
        nn.BatchNorm2d(128, momentum=0.82),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(256, momentum=0.8),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Flatten(),
        nn.Linear(256 * 5 * 5, 1),
        nn.Sigmoid()
    )

    def forward(self, img):
        validity = self.model(img)
        return validity

# %% [markdown]
# Initializing GAN components

# %%
generator = Generator(latent_dim).to(device)
discriminator = Discriminator().to(device)

adversarial_loss = nn.BCELoss()

optimizer_G = optim.Adam(generator.parameters()\
                         , lr=lr, betas=(beta1, beta2))
optimizer_D = optim.Adam(discriminator.parameters()\
                         , lr=lr, betas=(beta1, beta2))

# %% [markdown]
# Training

# %%
for epoch in range(num_epochs):
    for i, batch in enumerate(dataloader):

        real_images = batch[0].to(device)

        valid = torch.ones(real_images.size(0), 1, device=device)
        fake = torch.zeros(real_images.size(0), 1, device=device)

        real_images = real_images.to(device)

        optimizer_D.zero_grad()

        z = torch.randn(real_images.size(0), latent_dim, device=device)

        fake_images = generator(z)

        real_loss = adversarial_loss(discriminator\
                                     (real_images), valid)
        fake_loss = adversarial_loss(discriminator\
                                     (fake_images.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2

        d_loss.backward()
        optimizer_D.step()

        optimizer_G.zero_grad()

        gen_images = generator(z)

        g_loss = adversarial_loss(discriminator(gen_images), valid)
        g_loss.backward()
        optimizer_G.step()

        if (i + 1) % 100 == 0:
            print(
                f"Epoch [{epoch+1}/{num_epochs}]\
                        Batch {i+1}/{len(dataloader)} "
                f"Discriminator Loss: {d_loss.item():.4f} "
                f"Generator Loss: {g_loss.item():.4f}"
            )
    if (epoch + 1) % 10 == 0:
        with torch.no_grad():
            z = torch.randn(16, latent_dim, device=device)
            generated = generator(z).detach().cpu()
            grid = torchvision.utils.make_grid(generated,\
                                        nrow=4, normalize=True)
            plt.imshow(np.transpose(grid, (1, 2, 0)))
            plt.axis("off")
            plt.show()
# Out:
# Epoch [1/10]                        Batch 100/1563 Discriminator Loss: 0.4557 Generator Loss: 1.3363
# Epoch [1/10]                        Batch 200/1563 Discriminator Loss: 0.5476 Generator Loss: 1.2542
# Epoch [1/10]                        Batch 300/1563 Discriminator Loss: 0.6293 Generator Loss: 0.8984
# Epoch [1/10]                        Batch 400/1563 Discriminator Loss: 0.5139 Generator Loss: 1.2467
# Epoch [1/10]                        Batch 500/1563 Discriminator Loss: 0.6576 Generator Loss: 1.2406
# Epoch [1/10]                        Batch 600/1563 Discriminator Loss: 0.6309 Generator Loss: 1.0518
# Epoch [1/10]                        Batch 700/1563 Discriminator Loss: 0.5304 Generator Loss: 1.2071
# Epoch [1/10]                        Batch 800/1563 Discriminator Loss: 0.8814 Generator Loss: 0.6344
# Epoch [1/10]                        Batch 900/1563 Discriminator Loss: 0.6106 Generator Loss: 0.8661
# Epoch [1/10]                        Batch 1000/1563 Discriminator Loss: 0.7044 Generator Loss: 0.9618
# Epoch [1/10]                        Batch 1100/1563 Discriminator Loss: 0.6958 Generator Loss: 0.8033
# Epoch [1/10]                        Batch 1200/1563 Discriminator Loss: 0.6368 Generator Loss: 0.8310
# Epoch [1/10]                        Batch 1300/1563 Discriminator Loss: 0.6543 Generator Loss: 1.0538
# Epoch [1/10]                        Batch 1400/1563 Discriminator Loss: 0.7363 Generator Loss: 0.9104
# Epoch [1/10]                        Batch 1500/1563 Discriminator Loss: 0.7731 Generator Loss: 0.9671
# Epoch [2/10]                        Batch 100/1563 Discriminator Loss: 0.6735 Generator Loss: 1.0332
# Epoch [2/10]                        Batch 200/1563 Discriminator Loss: 0.6731 Generator Loss: 0.8481
# Epoch [2/10]                        Batch 300/1563 Discriminator Loss: 0.7236 Generator Loss: 0.9310
# Epoch [2/10]                        Batch 400/1563 Discriminator Loss: 0.6030 Generator Loss: 1.1409
# Epoch [2/10]                        Batch 500/1563 Discriminator Loss: 0.7940 Generator Loss: 0.7651
# Epoch [2/10]                        Batch 600/1563 Discriminator Loss: 0.6808 Generator Loss: 0.9093
# Epoch [2/10]                        Batch 700/1563 Discriminator Loss: 0.5196 Generator Loss: 1.0866
# Epoch [2/10]                        Batch 800/1563 Discriminator Loss: 0.5452 Generator Loss: 1.1391
# Epoch [2/10]                        Batch 900/1563 Discriminator Loss: 0.6928 Generator Loss: 0.9124
# Epoch [2/10]                        Batch 1000/1563 Discriminator Loss: 0.7852 Generator Loss: 1.0239
# Epoch [2/10]                        Batch 1100/1563 Discriminator Loss: 0.6609 Generator Loss: 1.1878
# Epoch [2/10]                        Batch 1200/1563 Discriminator Loss: 0.6294 Generator Loss: 1.0656
# Epoch [2/10]                        Batch 1300/1563 Discriminator Loss: 0.5557 Generator Loss: 1.0068
# Epoch [2/10]                        Batch 1400/1563 Discriminator Loss: 0.7493 Generator Loss: 0.9060
# Epoch [2/10]                        Batch 1500/1563 Discriminator Loss: 0.6373 Generator Loss: 0.8284
# Epoch [3/10]                        Batch 100/1563 Discriminator Loss: 0.5787 Generator Loss: 1.0005
# Epoch [3/10]                        Batch 200/1563 Discriminator Loss: 0.5194 Generator Loss: 1.2294
# Epoch [3/10]                        Batch 300/1563 Discriminator Loss: 0.7116 Generator Loss: 0.6980
# Epoch [3/10]                        Batch 400/1563 Discriminator Loss: 0.6329 Generator Loss: 1.0717
# Epoch [3/10]                        Batch 500/1563 Discriminator Loss: 0.7260 Generator Loss: 1.0136
# Epoch [3/10]                        Batch 600/1563 Discriminator Loss: 0.6600 Generator Loss: 0.8390
# Epoch [3/10]                        Batch 700/1563 Discriminator Loss: 0.4746 Generator Loss: 1.1424
# Epoch [3/10]                        Batch 800/1563 Discriminator Loss: 0.8126 Generator Loss: 0.6849
# Epoch [3/10]                        Batch 900/1563 Discriminator Loss: 0.6322 Generator Loss: 1.1594
# Epoch [3/10]                        Batch 1000/1563 Discriminator Loss: 0.6500 Generator Loss: 1.0701
# Epoch [3/10]                        Batch 1100/1563 Discriminator Loss: 0.5360 Generator Loss: 1.1149
# Epoch [3/10]                        Batch 1200/1563 Discriminator Loss: 0.5445 Generator Loss: 1.3633
# Epoch [3/10]                        Batch 1300/1563 Discriminator Loss: 1.1083 Generator Loss: 0.7454
# Epoch [3/10]                        Batch 1400/1563 Discriminator Loss: 0.4559 Generator Loss: 1.2951
# Epoch [3/10]                        Batch 1500/1563 Discriminator Loss: 0.9172 Generator Loss: 0.8130
# Epoch [4/10]                        Batch 100/1563 Discriminator Loss: 0.4833 Generator Loss: 1.4663
# Epoch [4/10]                        Batch 200/1563 Discriminator Loss: 0.5847 Generator Loss: 1.3511
# Epoch [4/10]                        Batch 300/1563 Discriminator Loss: 0.3476 Generator Loss: 1.4606
# Epoch [4/10]                        Batch 400/1563 Discriminator Loss: 0.6731 Generator Loss: 0.8320
# Epoch [4/10]                        Batch 500/1563 Discriminator Loss: 0.6051 Generator Loss: 1.1204
# Epoch [4/10]                        Batch 600/1563 Discriminator Loss: 0.6717 Generator Loss: 1.0546
# Epoch [4/10]                        Batch 700/1563 Discriminator Loss: 0.4945 Generator Loss: 1.3487
# Epoch [4/10]                        Batch 800/1563 Discriminator Loss: 0.5331 Generator Loss: 1.7067
# Epoch [4/10]                        Batch 900/1563 Discriminator Loss: 0.6781 Generator Loss: 0.9896
# Epoch [4/10]                        Batch 1000/1563 Discriminator Loss: 0.5824 Generator Loss: 0.8165
# Epoch [4/10]                        Batch 1100/1563 Discriminator Loss: 0.6670 Generator Loss: 0.7745
# Epoch [4/10]                        Batch 1200/1563 Discriminator Loss: 0.7906 Generator Loss: 0.5966
# Epoch [4/10]                        Batch 1300/1563 Discriminator Loss: 0.5270 Generator Loss: 0.8100
# Epoch [4/10]                        Batch 1400/1563 Discriminator Loss: 0.4313 Generator Loss: 0.7108
# Epoch [4/10]                        Batch 1500/1563 Discriminator Loss: 0.6198 Generator Loss: 0.8882
# Epoch [5/10]                        Batch 100/1563 Discriminator Loss: 0.7249 Generator Loss: 1.5215
# Epoch [5/10]                        Batch 200/1563 Discriminator Loss: 0.8143 Generator Loss: 1.4446
# Epoch [5/10]                        Batch 300/1563 Discriminator Loss: 0.4232 Generator Loss: 1.7725
# Epoch [5/10]                        Batch 400/1563 Discriminator Loss: 0.6686 Generator Loss: 0.6368
# Epoch [5/10]                        Batch 500/1563 Discriminator Loss: 0.4015 Generator Loss: 1.6071
# Epoch [5/10]                        Batch 600/1563 Discriminator Loss: 0.4939 Generator Loss: 1.1474
# Epoch [5/10]                        Batch 700/1563 Discriminator Loss: 0.7397 Generator Loss: 0.7613
# Epoch [5/10]                        Batch 800/1563 Discriminator Loss: 0
# Epoch [10/10]                        Batch 1400/1563 Discriminator Loss: 0.7584 Generator Loss: 1.0567
# Epoch [10/10]                        Batch 1500/1563 Discriminator Loss: 0.3897 Generator Loss: 1.0479

# %% [markdown]
# Evaluating the FID and IS metrics

# %%
pip install torch-fidelity
# Out:
# Requirement already satisfied: torch-fidelity in /usr/local/lib/python3.12/dist-packages (0.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch-fidelity) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from torch-fidelity) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from torch-fidelity) (1.16.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from torch-fidelity) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from torch-fidelity) (0.23.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch-fidelity) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->torch-fidelity) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->torch-fidelity) (3.0.2)

# %% [markdown]
# Loading the saved weights of the generator and the discriminator

# %%
# Instantiate your generator and discriminator models
# Make sure to use the same architecture as during training
generator = Generator(latent_dim).to(device)
discriminator = Discriminator().to(device)

# Load the saved state dictionaries
generator.load_state_dict(torch.load('generator.pth'))
discriminator.load_state_dict(torch.load('discriminator.pth'))

print("Generator and discriminator weights loaded.")
# Out:
# Generator and discriminator weights loaded.

# %% [markdown]
# Calculating the metrics

# %%
# !pip install torchmetrics[image] -q

import torch
import torchvision
import torchvision.transforms as transforms
from torchmetrics.image.inception import InceptionScore
from torchmetrics.image.fid import FrechetInceptionDistance
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

latent_dim = 100
num_images_to_eval = 100
batch_size = 128

class DummyGenerator(torch.nn.Module):
    def __init__(self, latent_dim):
        super().__init__()
        self.model = torch.nn.Sequential(
            torch.nn.Linear(latent_dim, 128),
            torch.nn.LeakyReLU(0.2),
            torch.nn.Linear(128, 256),
            torch.nn.BatchNorm1d(256),
            torch.nn.LeakyReLU(0.2),
            torch.nn.Linear(256, 3 * 32 * 32),
            torch.nn.Tanh()
        )
    def forward(self, z):
        img = self.model(z)
        img = img.view(img.size(0), 3, 32, 32)
        return img


generator.eval()

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)) # Normalize to [-1, 1] range
])

cifar10_test = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
real_dataloader = torch.utils.data.DataLoader(cifar10_test, batch_size=batch_size, shuffle=True)

print(f"\nGenerating {num_images_to_eval} fake images...")
fake_images = []
with torch.no_grad():
    for _ in tqdm(range(0, num_images_to_eval, batch_size)):
        current_batch_size = min(batch_size, num_images_to_eval - len(fake_images))
        if current_batch_size == 0:
            break

        noise = torch.randn(current_batch_size, latent_dim, device=device)
        generated = generator(noise)

        generated = (generated * 0.5 + 0.5) * 255
        fake_images.append(generated.to(torch.uint8).cpu())

fake_images = torch.cat(fake_images, dim=0)
print("Fake images generated successfully.")

print("\nCalculating Inception Score (IS)...")
inception_score = InceptionScore().to(device)
inception_score.update(fake_images.to(device))
is_mean, is_std = inception_score.compute()
print(f"Inception Score: {is_mean.item():.4f} ± {is_std.item():.4f}")

print("\nCalculating Frechet Inception Distance (FID)...")
fid = FrechetInceptionDistance(feature=64).to(device)

for real_batch, _ in tqdm(real_dataloader, desc="Processing real images for FID"):
    real_batch = (real_batch * 0.5 + 0.5) * 255
    fid.update(real_batch.to(device, dtype=torch.uint8), real=True)

fake_dataset = torch.utils.data.TensorDataset(fake_images)
fake_dataloader = torch.utils.data.DataLoader(fake_dataset, batch_size=batch_size)

for fake_batch in tqdm(fake_dataloader, desc="Processing fake images for FID"):
    fid.update(fake_batch[0].to(device), real=False)

fid_score = fid.compute()
print(f"Frechet Inception Distance (FID): {fid_score.item():.4f}")
# Out:
# Using device: cpu
#
# Generating 100 fake images...
# 100%|██████████| 1/1 [00:01<00:00,  1.66s/it]
# /usr/local/lib/python3.12/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `InceptionScore` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# Fake images generated successfully.
#
# Calculating Inception Score (IS)...
# Inception Score: 2.7934 ± 0.3576
#
# Calculating Frechet Inception Distance (FID)...
# Processing real images for FID: 100%|██████████| 79/79 [11:20<00:00,  8.61s/it]
# Processing fake images for FID: 100%|██████████| 1/1 [00:06<00:00,  6.20s/it]
# Frechet Inception Distance (FID): 0.4572
