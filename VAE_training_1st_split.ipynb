# %% [markdown]
# **Installing Dependecies**

# %%
# Install the library
# %pip install pythae
# Out:
# Requirement already satisfied: pythae in /usr/local/lib/python3.12/dist-packages (0.1.2)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pythae) (3.1.2)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from pythae) (2.37.2)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.12/dist-packages (from pythae) (2.0.2)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from pythae) (2.11.10)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from pythae) (1.6.1)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from pythae) (1.16.3)
# Requirement already satisfied: torch>=1.10.1 in /usr/local/lib/python3.12/dist-packages (from pythae) (2.8.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pythae) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from pythae) (4.15.0)
# Requirement already satisfied: dataclasses>=0.6 in /usr/local/lib/python3.12/dist-packages (from pythae) (0.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->pythae) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->pythae) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->pythae) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.1->pythae) (3.4.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio->pythae) (11.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pythae) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pythae) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.10.1->pythae) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.10.1->pythae) (3.0.3)

# %% [markdown]
# **Using gpu if available**

# %%
import torch
import torchvision.datasets as datasets

device = "cuda" if torch.cuda.is_available() else "cpu"

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# **Loading dataset, selecting specified split of dataset classes(i.e. no. of images from each class to keep) and defining split between train and eval data after random shuffling**

# %%
import numpy as np

cifar10_trainset = datasets.CIFAR10(root='../../data', train=True, download=True, transform=None)

data = np.array(cifar10_trainset.data)
labels = np.array(cifar10_trainset.targets)
selected_classes = ['cat', 'dog', 'horse', 'deer', 'bird']
selected_class_indices = [cifar10_trainset.class_to_idx[c] for c in selected_classes]
class_counts = {
    'cat': 4000,
    'dog': 1500,
    'horse': 1500,
    'deer': 1500,
    'bird': 1500
}

selected_data = []
selected_labels = []

for cls_name in selected_classes:
    cls_idx = cifar10_trainset.class_to_idx[cls_name]
    cls_mask = labels == cls_idx
    cls_data = data[cls_mask]
    chosen_indices = np.random.choice(len(cls_data), class_counts[cls_name], replace=False)
    selected_data.append(cls_data[chosen_indices])
    selected_labels.append(np.full(class_counts[cls_name], cls_idx))

imbalanced_data = np.concatenate(selected_data)
imbalanced_labels = np.concatenate(selected_labels)

perm = np.random.permutation(len(imbalanced_data))
imbalanced_data = imbalanced_data[perm]
imbalanced_labels = imbalanced_labels[perm]

split_idx = int(0.8 * len(imbalanced_data))
train_dataset = imbalanced_data[:split_idx].transpose(0, 3, 1, 2) / 255.0
eval_dataset  = imbalanced_data[split_idx:].transpose(0, 3, 1, 2) / 255.0

print("Train set size:", len(train_dataset))
print("Eval set size:", len(eval_dataset))

from collections import Counter
print("\nFinal training distribution:")
print(Counter(imbalanced_labels[:split_idx]))
print("Final eval distribution:")
print(Counter(imbalanced_labels[split_idx:]))
# Out:
# 100%|██████████| 170M/170M [01:22<00:00, 2.06MB/s]
# Train set size: 8000
# Eval set size: 2000
#
# Final training distribution:
# Counter({np.int64(3): 3203, np.int64(7): 1224, np.int64(5): 1194, np.int64(4): 1193, np.int64(2): 1186})
# Final eval distribution:
# Counter({np.int64(3): 797, np.int64(2): 314, np.int64(4): 307, np.int64(5): 306, np.int64(7): 276})

# %%
from pythae.models import VAE, VAEConfig
from pythae.trainers import BaseTrainerConfig
from pythae.pipelines.training import TrainingPipeline
from pythae.models.nn.benchmarks.cifar import Encoder_ResNet_VAE_CIFAR, Decoder_ResNet_AE_CIFAR

# %% [markdown]
# **Model Configuration**

# %%
config = BaseTrainerConfig(
    output_dir='my_model',
    learning_rate=1e-4,
    per_device_train_batch_size=64,
    per_device_eval_batch_size=64,
    num_epochs=50,
    optimizer_cls="AdamW",
    optimizer_params={"weight_decay": 0.05, "betas": (0.91, 0.99)}
)


model_config = VAEConfig(
    input_dim=(3, 32, 32),
    latent_dim=16
)

model = VAE(
    model_config=model_config,
    encoder=Encoder_ResNet_VAE_CIFAR(model_config),
    decoder=Decoder_ResNet_AE_CIFAR(model_config)
)

# %%
pipeline = TrainingPipeline(
    training_config=config,
    model=model
)

# %% [markdown]
# This code block trains the VAE using the train and eval datasets

# %%
pipeline(
    train_data=train_dataset,
    eval_data=eval_dataset
)
# Out:
# Preprocessing train data...
# INFO:pythae.pipelines.training:Preprocessing train data...
# Checking train dataset...
# INFO:pythae.pipelines.training:Checking train dataset...
# Preprocessing eval data...
#
# INFO:pythae.pipelines.training:Preprocessing eval data...
#
# Checking eval dataset...
# INFO:pythae.pipelines.training:Checking eval dataset...
# Using Base Trainer
#
# INFO:pythae.pipelines.training:Using Base Trainer
#
# Model passed sanity check !
# Ready for training.
#
# INFO:pythae.trainers.base_trainer.base_trainer:Model passed sanity check !
# Ready for training.
#
# Created my_model folder since did not exist.
#
# INFO:pythae.trainers.base_trainer.base_trainer:Created my_model folder since did not exist.
#
# Created my_model/VAE_training_2025-11-10_13-24-30.
# Training config, checkpoints and final model will be saved here.
#
# INFO:pythae.trainers.base_trainer.base_trainer:Created my_model/VAE_training_2025-11-10_13-24-30.
# Training config, checkpoints and final model will be saved here.
#
# Training params:
#  - max_epochs: 50
#  - per_device_train_batch_size: 64
#  - per_device_eval_batch_size: 64
#  - checkpoint saving every: None
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.91, 0.99)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.05
# )
# Scheduler: None
#
# INFO:pythae.trainers.base_trainer.base_trainer:Training params:
#  - max_epochs: 50
#  - per_device_train_batch_size: 64
#  - per_device_eval_batch_size: 64
#  - checkpoint saving every: None
# Optimizer: AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.91, 0.99)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.05
# )
# Scheduler: None
#
# Successfully launched training !
#
# INFO:pythae.trainers.base_trainer.base_trainer:Successfully launched training !
# Training of epoch 1/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 1/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 90.5974
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 90.5974
# Eval loss: 71.6241
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 71.6241
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 2/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 2/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 61.6228
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 61.6228
# Eval loss: 55.945
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 55.945
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 3/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 3/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 54.4207
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 54.4207
# Eval loss: 52.1971
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 52.1971
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 4/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 4/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 51.7657
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 51.7657
# Eval loss: 50.5426
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 50.5426
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 5/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 5/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 50.4477
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 50.4477
# Eval loss: 49.1422
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 49.1422
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 6/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 6/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 49.5789
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 49.5789
# Eval loss: 48.6063
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 48.6063
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 7/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 7/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 49.0827
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 49.0827
# Eval loss: 48.0767
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 48.0767
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 8/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 8/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 48.7001
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 48.7001
# Eval loss: 48.0263
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 48.0263
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 9/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 9/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 48.3841
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 48.3841
# Eval loss: 47.7607
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 47.7607
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 10/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 10/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 47.9083
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 47.9083
# Eval loss: 46.8904
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 46.8904
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 11/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 11/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 47.3934
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 47.3934
# Eval loss: 46.7216
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 46.7216
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 12/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 12/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 47.1677
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 47.1677
# Eval loss: 46.5849
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 46.5849
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 13/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 13/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.9624
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.9624
# Eval loss: 46.32
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 46.32
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 14/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 14/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.8259
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.8259
# Eval loss: 46.4882
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 46.4882
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 15/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 15/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.7254
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.7254
# Eval loss: 46.447
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 46.447
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 16/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 16/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.7253
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.7253
# Eval loss: 46.1225
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 46.1225
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 17/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 17/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.6422
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.6422
# Eval loss: 46.1371
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 46.1371
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 18/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 18/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.5166
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.5166
# Eval loss: 46.2048
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 46.2048
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 19/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 19/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.5521
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.5521
# Eval loss: 45.9885
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.9885
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 20/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 20/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.4822
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.4822
# Eval loss: 46.0706
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 46.0706
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 21/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 21/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.3727
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.3727
# Eval loss: 45.9026
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.9026
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 22/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 22/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.3191
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.3191
# Eval loss: 45.7676
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.7676
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 23/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 23/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.3428
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.3428
# Eval loss: 45.7825
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.7825
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 24/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 24/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.2564
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.2564
# Eval loss: 45.8538
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.8538
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 25/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 25/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.2132
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.2132
# Eval loss: 46.0861
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 46.0861
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 26/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 26/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.1975
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.1975
# Eval loss: 45.9853
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.9853
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 27/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 27/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.1816
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.1816
# Eval loss: 45.566
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.566
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 28/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 28/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.0885
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.0885
# Eval loss: 45.7391
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.7391
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 29/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 29/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.1007
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.1007
# Eval loss: 45.7242
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.7242
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 30/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 30/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.0625
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.0625
# Eval loss: 45.456
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.456
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 31/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 31/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.0221
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.0221
# Eval loss: 45.5538
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.5538
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 32/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 32/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 46.0336
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 46.0336
# Eval loss: 45.8492
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.8492
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 33/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 33/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.9859
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.9859
# Eval loss: 45.8562
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.8562
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 34/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 34/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.9996
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.9996
# Eval loss: 45.69
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.69
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 35/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 35/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.9367
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.9367
# Eval loss: 45.4097
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.4097
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 36/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 36/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.8635
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.8635
# Eval loss: 45.9797
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.9797
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 37/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 37/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.8213
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.8213
# Eval loss: 45.4128
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.4128
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 38/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 38/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.8572
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.8572
# Eval loss: 45.4609
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.4609
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 39/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 39/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.8356
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.8356
# Eval loss: 45.5604
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.5604
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 40/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 40/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.8253
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.8253
# Eval loss: 45.5974
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.5974
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 41/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 41/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.7098
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.7098
# Eval loss: 45.3484
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.3484
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 42/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 42/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.7459
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.7459
# Eval loss: 45.8001
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.8001
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 43/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 43/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.7781
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.7781
# Eval loss: 45.5111
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.5111
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 44/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 44/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.7466
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.7466
# Eval loss: 45.6651
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.6651
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 45/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 45/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.7109
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.7109
# Eval loss: 45.6667
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.6667
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 46/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 46/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.7183
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.7183
# Eval loss: 45.1667
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.1667
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 47/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 47/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.7001
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.7001
# Eval loss: 45.4002
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.4002
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 48/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 48/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.6829
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.6829
# Eval loss: 45.4354
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.4354
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 49/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 49/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.641
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.641
# Eval loss: 45.4133
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.4133
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training of epoch 50/50:   0%|          | 0/125 [00:00<?, ?batch/s]
# Eval of epoch 50/50:   0%|          | 0/32 [00:00<?, ?batch/s]
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Train loss: 45.5994
# INFO:pythae.trainers.base_trainer.base_trainer:Train loss: 45.5994
# Eval loss: 45.3362
# INFO:pythae.trainers.base_trainer.base_trainer:Eval loss: 45.3362
# --------------------------------------------------------------------------
# INFO:pythae.trainers.base_trainer.base_trainer:--------------------------------------------------------------------------
# Training ended!
# INFO:pythae.trainers.base_trainer.base_trainer:Training ended!
# Saved final model in my_model/VAE_training_2025-11-10_13-24-30/final_model
# INFO:pythae.trainers.base_trainer.base_trainer:Saved final model in my_model/VAE_training_2025-11-10_13-24-30/final_model

# %%
import os
from pythae.models import AutoModel

# %% [markdown]
# **Loading the trained model**

# %%
last_training = sorted(os.listdir('my_model'))[-1]
trained_model = AutoModel.load_from_folder(os.path.join('my_model', last_training, 'final_model'))

# %%
from pythae.samplers import NormalSampler

# %% [markdown]
# # Sampling from a standard normal or Gaussian Mixture for generating artifical images

# %% [markdown]
# **Sampling using normal sampler**

# %%
# create normal sampler
normal_samper = NormalSampler(
    model=trained_model
)

# %%
# sample
gen_data = normal_samper.sample(
    num_samples=25
)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **Normal Sampling generation results**

# %%
# show results with normal sampler
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(10, 10))

for i in range(5):
    for j in range(5):
        # Transpose the dimensions to (height, width, channels)
        axes[i][j].imshow(gen_data[i*5 +j].cpu().squeeze(0).permute(1, 2, 0))
        axes[i][j].axis('off')
plt.tight_layout(pad=0.)

# %%
from pythae.samplers import GaussianMixtureSampler, GaussianMixtureSamplerConfig

# %% [markdown]
# **GMM sampling generation results**

# %%
# set up GMM sampler config
gmm_sampler_config = GaussianMixtureSamplerConfig(
    n_components=10
)

# create gmm sampler
gmm_sampler = GaussianMixtureSampler(
    sampler_config=gmm_sampler_config,
    model=trained_model
)

# fit the sampler
gmm_sampler.fit(train_dataset)

# %%
# sample
gen_data = gmm_sampler.sample(
    num_samples=25
)

# %%
# show results with gmm sampler
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(10, 10))

for i in range(5):
    for j in range(5):
        axes[i][j].imshow(gen_data[i*5 +j].cpu().squeeze(0).permute(1, 2, 0))
        axes[i][j].axis('off')
plt.tight_layout(pad=0.)

# %% [markdown]
# ## ... the other samplers work the same

# %% [markdown]
# ## Visualizing reconstructions
#
# Here we are selecting data from the eval data and then passing it to the trained VAE architecture. After that, we compare the reconstruted data from the original data to see the quality of the reconstructed images

# %%
reconstructions = trained_model.reconstruct(torch.from_numpy(eval_dataset[:25]).to(device).float()).detach().cpu()

# %% [markdown]
# **Original eval data points/images**

# %%
# show original
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(10, 10))

for i in range(5):
    for j in range(5):
        axes[i][j].imshow(eval_dataset[:25][i*5 + j].transpose(1, 2, 0))
        axes[i][j].axis('off')
plt.tight_layout(pad=0.)

# %% [markdown]
# **Reconstructed images**

# %%
# show reconstructions
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(10, 10))

for i in range(5):
    for j in range(5):
        axes[i][j].imshow(reconstructions[i*5 + j].cpu().squeeze(0).permute(1, 2, 0))
        axes[i][j].axis('off')
plt.tight_layout(pad=0.)

# %% [markdown]
# **FID and IS score**

# %%
# Install torchmetrics with image dependencies if not already installed
# %pip install torchmetrics[image]

import torch
from torchmetrics.image.fid import FrechetInceptionDistance
from torchmetrics.image.inception import InceptionScore
import torchvision.transforms as T

# Define a function to calculate FID
def calculate_fid(real_images, generated_images, device, batch_size=64):
    fid = FrechetInceptionDistance(feature=2048).to(device)
    # Ensure images are in the correct format (uint8 and C, H, W)
    real_images = (real_images * 255).byte()
    generated_images = (generated_images * 255).byte()

    for i in range(0, real_images.size(0), batch_size):
        fid.update(real_images[i:i+batch_size].to(device), real=True)
    for i in range(0, generated_images.size(0), batch_size):
        fid.update(generated_images[i:i+batch_size].to(device), real=False)

    return fid.compute()

# Define a function to calculate Inception Score
def calculate_is(images, device, batch_size=64):
    is_score = InceptionScore().to(device)
    # Ensure images are in the correct format (uint8 and C, H, W)
    images = (images * 255).byte()

    for i in range(0, images.size(0), batch_size):
        is_score.update(images[i:i+batch_size].to(device))

    return is_score.compute()

# Generate a larger number of samples for evaluation (e.g., 1000)
num_eval_samples = 1000
gen_data_eval = normal_samper.sample(
    num_samples=num_eval_samples
).cpu()

# Use a subset of the real training data for evaluation
real_data_eval = torch.from_numpy(train_dataset[torch.randperm(len(train_dataset))[:num_eval_samples]]).cpu()


# Calculate FID score
fid_score = calculate_fid(real_data_eval, gen_data_eval, device)
print(f"FID score: {fid_score.item()}")

# Calculate Inception Score
# Note: Inception Score usually requires a larger number of samples (e.g., 10,000) for reliable results
# We will use 1000 samples here for demonstration purposes
is_mean, is_std = calculate_is(gen_data_eval, device)
print(f"Inception Score (mean): {is_mean.item()}, (std): {is_std.item()}")
# Out:
# Collecting torchmetrics[image]
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics[image]) (2.0.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.12/dist-packages (from torchmetrics[image]) (25.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics[image]) (2.8.0+cu126)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics[image])
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting torch-fidelity<=0.4.0 (from torchmetrics[image])
#   Downloading torch_fidelity-0.3.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: torchvision>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from torchmetrics[image]) (0.23.0+cu126)
# Requirement already satisfied: scipy>1.0.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics[image]) (1.16.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.8.0->torchmetrics[image]) (75.2.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.8.0->torchmetrics[image]) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (3.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from torch-fidelity<=0.4.0->torchmetrics[image]) (11.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch-fidelity<=0.4.0->torchmetrics[image]) (4.67.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->torchmetrics[image]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->torchmetrics[image]) (3.0.3)
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torch_fidelity-0.3.0-py3-none-any.whl (37 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 54.2 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, torch-fidelity
# Successfully installed lightning-utilities-0.15.2 torch-fidelity-0.3.0 torchmetrics-1.8.2
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
# 100%|██████████| 91.2M/91.2M [00:00<00:00, 165MB/s]
# FID score: 306.06561279296875
# /usr/local/lib/python3.12/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `InceptionScore` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# Inception Score (mean): 1.7952346801757812, (std): 0.12211142480373383

# %% [markdown]
# ### Report on Model Training and Evaluation
#
# **Model Used:** VAE (Variational Autoencoder)
#
# **Dataset:** CIFAR10
#
# **Key Training Configuration:**
# *   **Output Directory:** `my_model`
# *   **Learning Rate:** 1e-4
# *   **Per Device Train Batch Size:** 64
# *   **Per Device Eval Batch Size:** 64
# *   **Number of Epochs:** 50
# *   **Optimizer:** AdamW
# *   **Optimizer Parameters:** `weight_decay=0.05`, `betas=(0.91, 0.99)`
#
# **Model Configuration:**
# *   **Input Dimension:** (3, 32, 32) - corresponding to color CIFAR10 images
# *   **Latent Dimension:** 16
# *   **Encoder/Decoder Architectures:** ResNet-based architectures adapted for CIFAR.
#
# **Training Process:**
# The VAE model was trained for 10 epochs on the CIFAR10 training dataset. The training and evaluation losses were monitored during training.
#
# **Evaluation Metrics and Results:**
#
# *   **Sampler Used for Evaluation:** Normal Sampler (used to generate samples for FID and IS calculation)
# *   **Number of Samples Used for Evaluation:** 1000 (for both FID and IS)
# *   **Evaluation Device:** CUDA (GPU)
#
# The following metrics were calculated using the `torchmetrics` library:
#
# *   **Frechet Inception Distance (FID):** Measures the distance between the feature distributions of real and generated images. A *lower* FID score indicates better quality and diversity of generated images (closer to the real data distribution).
#     *   **FID Score:** **306.0656**
#
# *   **Inception Score (IS):** Measures the quality (cleanness) and diversity of generated images. A *higher* Inception Score indicates better quality and diversity.
#     *   **Inception Score (mean):** **1.7952**
#     *   **Inception Score (std):** **0.1221**
